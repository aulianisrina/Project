# %% [markdown]
# ### Importing Required Libraries

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
import shutil
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Specifying Image Size, Batch Size, Epochs, Channels

# %%
Image_Size = 256
Batch_Size = 64
Channels = 3
Epochs = 50

# %% [markdown]
# ### Loading Dataset

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/brain-mri-scans-for-brain-tumor-classification/data",
    shuffle = True,
    image_size = (Image_Size, Image_Size),
    batch_size = Batch_Size
)
# Out:
# Found 1311 files belonging to 4 classes.

# %% [markdown]
# ### Class Names

# %%
classes = dataset.class_names
classes
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ### Length of Dataset

# %%
len(dataset)
# Out:
# 21

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (64, 256, 256, 3)
# [1 3 1 3 0 3 2 2 2 1 3 3 2 0 2 2 1 0 3 1 0 3 3 1 3 0 0 3 1 0 1 2 2 2 1 1 0
#  3 1 2 3 2 2 0 1 3 2 3 0 3 1 0 3 1 3 0 2 0 2 1 2 3 3 3]

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(num=10, figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(classes[label_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### Train Test Split -

# %% [markdown]
# 80% --> Training, 10% --> Validation, 10% --> Testing

# %%
def dataset_get_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=42)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = dataset_get_partitions_tf(dataset)

# %%
print(len(train_ds))
print(len(val_ds))
print(len(test_ds))
# Out:
# 16
# 2
# 3

# %% [markdown]
# ### Shuffling Data

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# ### Resize and Rescale Layer

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(Image_Size, Image_Size),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %% [markdown]
# ### Data Augmentation Layer

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# ### Model Building

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 200x 200 with 3 bytes color
    # The first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a dense layer
    tf.keras.layers.Flatten(),
    # 128 neuron in the fully-connected layer
    tf.keras.layers.Dense(128, activation='relu'),
    # 5 output neurons for 5 classes with the softmax activation
    tf.keras.layers.Dense(4, activation='softmax')
])

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 392996 (1.50 MB)
# Trainable params: 392996 (1.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Setting up Learning Rate and Optimizer

# %%
# Implement learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

# %% [markdown]
# ### Compiling the Model

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %% [markdown]
# ### Setting up Early Stopping

# %%
# Implement early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# %% [markdown]
# ### Training Model

# %%
# Train the model with more epochs
history = model.fit(
    train_ds,
    epochs=Epochs,  # Increase the number of epochs
    batch_size=Batch_Size,
    verbose=1,
    validation_data=val_ds,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 17s 176ms/step - loss: 10.1322 - accuracy: 0.3691 - val_loss: 1.2220 - val_accuracy: 0.3984
# Epoch 2/50
# 16/16 [==============================] - 1s 68ms/step - loss: 1.0483 - accuracy: 0.5244 - val_loss: 0.9870 - val_accuracy: 0.6094
# Epoch 3/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.8202 - accuracy: 0.6758 - val_loss: 0.8829 - val_accuracy: 0.6172
# Epoch 4/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.6522 - accuracy: 0.7314 - val_loss: 0.6735 - val_accuracy: 0.7734
# Epoch 5/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.4839 - accuracy: 0.8115 - val_loss: 0.6081 - val_accuracy: 0.7422
# Epoch 6/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.4203 - accuracy: 0.8398 - val_loss: 0.4839 - val_accuracy: 0.8359
# Epoch 7/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.3298 - accuracy: 0.8809 - val_loss: 0.4245 - val_accuracy: 0.8594
# Epoch 8/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.3207 - accuracy: 0.8740 - val_loss: 0.3515 - val_accuracy: 0.8828
# Epoch 9/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.2541 - accuracy: 0.8955 - val_loss: 0.3634 - val_accuracy: 0.8594
# Epoch 10/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.1965 - accuracy: 0.9277 - val_loss: 0.2226 - val_accuracy: 0.9453
# Epoch 11/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.1338 - accuracy: 0.9619 - val_loss: 0.2475 - val_accuracy: 0.9531
# Epoch 12/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.1073 - accuracy: 0.9619 - val_loss: 0.2554 - val_accuracy: 0.8984
# Epoch 13/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0676 - accuracy: 0.9824 - val_loss: 0.2466 - val_accuracy: 0.9375
# Epoch 14/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0678 - accuracy: 0.9736 - val_loss: 0.3547 - val_accuracy: 0.9297
# Epoch 15/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0826 - accuracy: 0.9746 - val_loss: 0.2451 - val_accuracy: 0.9141
# Epoch 16/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0577 - accuracy: 0.9834 - val_loss: 0.2738 - val_accuracy: 0.9297
# Epoch 17/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0388 - accuracy: 0.9902 - val_loss: 0.2644 - val_accuracy: 0.9297
# Epoch 18/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0417 - accuracy: 0.9902 - val_loss: 0.2645 - val_accuracy: 0.9375
# Epoch 19/50
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0260 - accuracy: 0.9932 - val_loss: 0.3026 - val_accuracy: 0.9297
# Epoch 20/50
# 16/16 [==============================] - 1s 68ms/step - loss: 0.0162 - accuracy: 0.9980 - val_loss: 0.2719 - val_accuracy: 0.9453

# %% [markdown]
# ### Evaluating Model on test data

# %%
scores = model.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 1s 28ms/step - loss: 0.2214 - accuracy: 0.9271

# %% [markdown]
# ### Plotting Loss and Accuracy Curve

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Plotting the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(acc) + 1), acc, label='Training Accuracy')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(range(1, len(loss) + 1), loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Looking at Predictions

# %%
# Get some random samples from the test dataset
sample_images = []
sample_labels = []
for images, labels in test_ds.take(1):
    sample_images = images.numpy()
    sample_labels = labels.numpy()

# Make predictions on the random samples
predictions = model.predict(sample_images)

# Visualize random samples with actual and predicted labels
num_samples = len(sample_images)
num_rows = 3
num_cols = 4
plt.figure(figsize=(12, 12))
for i in range(min(num_samples, num_rows * num_cols)):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(sample_images[i].astype("uint8"))
    actual_label = classes[sample_labels[i]]
    predicted_label = classes[np.argmax(predictions[i])]
    title = f"Actual: {actual_label}\nPredicted: {predicted_label}"
    plt.title(title)
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 2/2 [==============================] - 1s 11ms/step
